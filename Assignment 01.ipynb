# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print('Ammarah Khan')
print('Shahbaz Khan')
print('25-04-2007')
# Out:
# Ammarah Khan
# Shahbaz Khan
# 25-04-2007

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
bio = 'I am ammarah. I am 18 years old. I am doing 4 years B.Ed(honors) from GECE Hussainabad. I am in 2nd semester'
print(bio)
type(bio)
id(bio)
# Out:
# I am ammarah. I am 18 years old. I am doing 4 years B.Ed(honors) from GECE Hussainabad. I am in 2nd semester
# 2083518464528

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
print(20+10)
print(20-10)
print(20*10)
print(20/10)
print(2**3)
print(20%10)
print(20//10)
# Out:
# 30
# 10
# 200
# 2.0
# 8
# 0
# 2

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
english = 70
islamiat = 80
maths = 90
total_marks = 300

obtained_marks = english + islamiat + maths
print (obtained_marks)
percentage = (obtained_marks / total_marks) * 100
print (percentage)
# Out:
# 240
# 80.0
